# %%
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms
import torchvision.transforms.functional as TF

import cv2
from PIL import Image
import matplotlib.pyplot as plt                        
# %matplotlib inline  

import datetime

# %% [markdown]
# __Data:__ Build the dataloaders. Be sure every watermarked image has his corresponding clean image.

# %%
#all the pathes
path_datafolder_pureimage = ".\\targets\\split"
path_datafolder_watermarked = ".\\inputs\\split"

# %%
from glob import glob

#path images with watermark
wm_images = np.array(glob("./inputs/split/*"))
#path original images
or_images = np.array(glob("./targets/split/*"))


if (len(wm_images)!=len(or_images)):
    print ("Error: The number of watermarked images and pure images isn't the same\n")
else:
    l_index = len(wm_images)
       
print ("Count watermarked images: {}\t Count pure images: {}".format(len(wm_images),len(or_images)))
# Out:
# Count watermarked images: 57324	 Count pure images: 57324

# %% [markdown]
# __Dataset:__ Modify the one from the pytorch tutorial. I want to link my clean image to the watermarked image. So that I can use the pytorch DataLoader

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
class MarkedAndPureDataset(Dataset):
    """Clean and Watermarked images."""

    def __init__(self, paths_pure, paths_wm, transform=None):
        """
        Args:
            paths_pure (list): list of pathes, one path to one pure image
            paths_wm (list): list of pathes, one path to one pure image
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.paths_pure = paths_pure
        self.paths_wm = paths_wm
        self.transform = transform

    def __len__(self):
        if len(self.paths_pure) == len(self.paths_wm):
            return len(self.paths_pure)
        else:
            return None

    def __getitem__(self, idx):
        img_name_pure = self.paths_pure[idx]
        img_name_wm = self.paths_wm[idx]
        if img_name_pure[img_name_pure.find("frame")+5:] == img_name_wm[img_name_wm.find("blend")+5:]:
            image_pure = Image.open(img_name_pure)
            image_wm = Image.open(img_name_wm)
            if self.transform:
                image_pure = self.transform(image_pure)
                image_wm = self.transform(image_wm)
        else:
            print("Error: Mappingerror Input - Target")
            image_pure = None
            image_wm = None
        #sample = image_pure,image_wm

        
            

        return image_pure, image_wm
    
    def info(self):
        return self.paths_wm

# %%
datas = MarkedAndPureDataset(or_images,wm_images,transform=transforms.ToTensor())
dataloader = DataLoader(datas, batch_size=8, shuffle=True)

# %% [markdown]
# __Check the dataloader:__ print some pure and the corresponding watermarked images

# %%
##print one batch, 4 pure & 4 watermarked images
for p_im, wm_im in dataloader:
    fig = plt.figure(figsize=(16,16))
    for ind in range(4):

        ax = fig.add_subplot(2,4,ind+1,xticks=[], yticks=[])
        plt.imshow(TF.to_pil_image(p_im[ind]))
        ax.set_title('Before'+str(ind+1))
        ax = fig.add_subplot(2,4,ind+5,xticks=[], yticks=[])
        plt.imshow(TF.to_pil_image(wm_im[ind]))
        ax.set_title('After'+str(ind+1))
          
    break

# %% [markdown]
# __Model:__ Build the model

# %%
import torch.nn as nn
import torch.nn.functional as F

class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv1 = nn.Conv2d(3, 12, 5, padding=2)
        self.conv2 = nn.Conv2d(12, 24, 5, padding =2)
        self.bn2 = nn.BatchNorm2d(24)
        self.conv3 = nn.Conv2d(24,48,5,padding=2)
        self.bn3 = nn.BatchNorm2d(48)
        self.conv4 = nn.Conv2d(48,96,5,padding=2)
        self.bn4 = nn.BatchNorm2d(96)
        
        self.conv5 = nn.Conv2d(96,48,5,padding=2)
        self.bn5 = nn.BatchNorm2d(48)
        self.conv6 = nn.Conv2d(48,24,5,padding=2)
        self.bn6 = nn.BatchNorm2d(24)
        
        self.conv7 = nn.Conv2d(24,12,5,padding=2)
        self.bn7 = nn.BatchNorm2d(12)
        self.conv_out = nn.Conv2d(12,3,5,padding=2)
        
        

    def forward(self, x):
        
        x = F.relu(self.conv1(x))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn4(self.conv4(x)))
        x = F.relu(self.bn5(self.conv5(x)))
        x = F.relu(self.bn6(self.conv6(x)))
        x = F.relu(self.bn7(self.conv7(x)))
        x = F.sigmoid(self.conv_out(x))
        
        return x
    
deNoiser = Model()
print (deNoiser)
if torch.cuda.is_available():
    deNoiser.cuda()
    print("Cuda is available: {}".format(torch.cuda.is_available()))
# Out:
# Model(
#   (conv1): Conv2d(3, 12, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(12, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(24, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (bn3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(48, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (bn4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(96, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (bn5): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv2d(48, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (bn6): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv7): Conv2d(24, 12, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (bn7): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv_out): Conv2d(12, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
# )
# Cuda is available: True

# %% [markdown]
# __Loss function and optimizer:__
# Choose a Loss: No classification, more like a regression, thats why I start with MSE

# %%
criterion = nn.MSELoss()

#try this one out
optimizer = torch.optim.Adam(deNoiser.parameters(), lr=0.001)

# %%
def denoise_image(image):
    trnsf = transforms.ToTensor()
    image_Tensor = trnsf(image)
    if torch.cuda.is_available():
        image_Tensor = image_Tensor.cuda()
    output = deNoiser(image_Tensor.view(-1,3,480,212))
    output = output.cpu()
    return TF.to_pil_image(output.squeeze())

# %% [markdown]
# __Train & Validation:__

# %%
#search an image for validation
valid_image_path = wm_images[598]
valid_image = Image.open(valid_image_path)
plt.imshow(valid_image)

# %%
#save the picture
valid_image.save("./data_model#1/valid_pic_10percent_#1_0_damaged.png")

# %%
print("Starttime: {}".format(datetime.datetime.now().time()))

epoch = 5


counter = 0

for e in range (1,epoch+1):
    
    #I'm not sure if the loss in this case will help me
    loss_train = []
    
    
    for pu_im, wa_im in dataloader:
        
        if torch.cuda.is_available():
            pu_im, wa_im = pu_im.cuda(), wa_im.cuda()
        
        optimizer.zero_grad()
        output = deNoiser(wa_im.view(-1,3,480,212))
        loss = criterion(output, pu_im.view(-1,3,480,212))
        loss.backward()
        optimizer.step()
        loss_train.append(loss.item())
        
    #print_cuda_mem()    
    train_loss_mean = torch.tensor(loss_train).mean()   
    print("Epoch: {}\tTrain_loss:  {}".format(e,train_loss_mean))
    print(datetime.datetime.now().time())
    ###denoise a watermarked pic after each epoch and save it
    ###in the first step it's always the same pic
    valid1 = denoise_image(Image.open(valid_image_path))
    
    valid1.save("./data_model#1/valid_pic_10percent_#1_"+str(e)+".png")  
    
    torch.save(deNoiser.state_dict(), "./deNoiser_10percent_#1.pt")
# Out:
# Starttime: 19:35:37.656706
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch: 1	Train_loss:  0.0015305338893085718
# 22:45:27.098847
# Epoch: 2	Train_loss:  0.0007177976076491177
# 01:56:42.037225
# Epoch: 3	Train_loss:  0.0004890795680694282
# 05:04:08.101426
# Epoch: 4	Train_loss:  0.00036875263322144747
# 08:13:01.987281
# Epoch: 5	Train_loss:  0.00028870420646853745
# 11:36:45.359683

# %%
#save_weights for cpu use:
deNoiser.cpu()
torch.save(deNoiser.state_dict(), "./data_model#1/deNoiser_10percent_#1_cpu.pt")

# %%
#print the validation image after every epoch
#with the damaged image there are 6 images. --> 2*3 table
list_path_validation_images = glob("./data_model#1/valid_pic*.png")
list_images = []
for im in list_path_validation_images:
    list_images.append(cv2.cvtColor(cv2.imread(im), cv2.COLOR_BGR2RGB))



fig = plt.figure(figsize=(16,16))
for ind in range(6):
    ax = fig.add_subplot(2,3,ind+1,xticks=[], yticks=[])
    plt.imshow(list_images[ind])
    ax.set_title('Epoch '+str(ind))

# %% [markdown]
# ### Conclusion:
# Allready after one epoch of training the black bars are gone! But the picture (Epoch1) is not as bright at it should be. This becomes better from epoch to epoch.
#
# This was the first step. Let' start experimenting with other model architectures
